# %%
import nibabel as nib
import numpy as np
import os
import glob

label_dir = "/home/user/auto-annotation/auto-annotation/dataset/femur-bone/data/label/CT2"
# Get all .nii.gz files in the directory
nifti_files = glob.glob(os.path.join(label_dir, "*.nii.gz"))
print(f"\nFound {len(nifti_files)} NIfTI files in {label_dir}")
print("="*80)

success = True

# Process each file
for file_path in sorted(nifti_files):
    try:
        # Load the NIfTI file
        img = nib.load(file_path)
        data = img.get_fdata()
        
        # Get unique labels
        unique_labels = np.unique(data)
        if len(unique_labels) != 5:
            success = False
        
        # Get just the filename for cleaner output
        filename = os.path.basename(file_path)
        
        print(f"{filename}:")
        print(f"  Data shape: {data.shape}")
        print(f"  Data type: {data.dtype}")
        print(f"  Number of unique labels: {len(unique_labels)}")
        print(f"  Label analysis:")
        
        # Calculate volume (voxel count) for each unique label
        total_voxels = data.size
        for label in unique_labels:
            voxel_count = np.sum(data == label)
            percentage = (voxel_count / total_voxels) * 100
            print(f"    Label {label:>6}: {voxel_count:>8} voxels ({percentage:>6.2f}%)")
        
        print(f"  Total voxels: {total_voxels}")
        print("-" * 60)
        
    except Exception as e:
        filename = os.path.basename(file_path)
        print(f"Error loading {filename}: {str(e)}")
        print("-" * 60)

print("Analysis complete!")
print("="*80)
print("Success Status: ", success)
# Out:
# Found 15 NIfTI files in /home/user/auto-annotation/auto-annotation/dataset/femur-bone/data/label/CT2
# ================================================================================
# RG018_right_CT2.nii.gz:
#   Data shape: (256, 512, 177)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 19340147 voxels ( 83.36%)
#     Label    1.0:   160548 voxels (  0.69%)
#     Label    2.0:    92877 voxels (  0.40%)
#     Label    3.0:  2990151 voxels ( 12.89%)
#     Label    4.0:   616021 voxels (  2.66%)
#   Total voxels: 23199744
# ------------------------------------------------------------
# RP036_left_CT2.nii.gz:
#   Data shape: (256, 512, 169)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 17160336 voxels ( 77.47%)
#     Label    1.0:   143766 voxels (  0.65%)
#     Label    2.0:   121483 voxels (  0.55%)
#     Label    3.0:  3989688 voxels ( 18.01%)
#     Label    4.0:   735895 voxels (  3.32%)
#   Total voxels: 22151168
# ------------------------------------------------------------
# RP036_right_CT2.nii.gz:
#   Data shape: (256, 512, 169)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 17590116 voxels ( 79.41%)
#     Label    1.0:   149032 voxels (  0.67%)
#     Label    2.0:   110263 voxels (  0.50%)
#     Label    3.0:  3640301 voxels ( 16.43%)
#     Label    4.0:   661456 voxels (  2.99%)
#   Total voxels: 22151168
# ------------------------------------------------------------
# RT023_left_CT2.nii.gz:
#   Data shape: (256, 512, 182)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 18810642 voxels ( 78.85%)
#     Label    1.0:   160618 voxels (  0.67%)
#     Label    2.0:   119140 voxels (  0.50%)
#     Label    3.0:  4127528 voxels ( 17.30%)
#     Label    4.0:   637176 voxels (  2.67%)
#   Total voxels: 23855104
# ------------------------------------------------------------
# RT023_right_CT2.nii.gz:
#   Data shape: (256, 512, 182)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 18984769 voxels ( 79.58%)
#     Label    1.0:   163909 voxels (  0.69%)
#     Label    2.0:   113090 voxels (  0.47%)
#     Label    3.0:  3983886 voxels ( 16.70%)
#     Label    4.0:   609450 voxels (  2.55%)
#   Total voxels: 23855104
# ------------------------------------------------------------
# SB032_left_CT2.nii.gz:
#   Data shape: (256, 512, 182)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 19248816 voxels ( 80.69%)
#     Label    1.0:   164982 voxels (  0.69%)
#     Label    2.0:   103721 voxels (  0.43%)
#     Label    3.0:  3666681 voxels ( 15.37%)
#     Label    4.0:   670904 voxels (  2.81%)
#   Total voxels: 23855104
# ------------------------------------------------------------
# SB032_right_CT2.nii.gz:
#   Data shape: (256, 512, 182)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 19212763 voxels ( 80.54%)
#     Label    1.0:   178008 voxels (  0.75%)
#     Label    2.0:   107676 voxels (  0.45%)
#     Label    3.0:  3702466 voxels ( 15.52%)
#     Label    4.0:   654191 voxels (  2.74%)
#   Total voxels: 23855104
# ------------------------------------------------------------
# SL015_left_CT2.nii.gz:
#   Data shape: (256, 512, 168)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 15922715 voxels ( 72.31%)
#     Label    1.0:   128752 voxels (  0.58%)
#     Label    2.0:    97201 voxels (  0.44%)
#     Label    3.0:  5310392 voxels ( 24.12%)
#     Label    4.0:   561036 voxels (  2.55%)
#   Total voxels: 22020096
# ------------------------------------------------------------
# SL015_right_CT2.nii.gz:
#   Data shape: (256, 512, 168)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 16288465 voxels ( 73.97%)
#     Label    1.0:   128898 voxels (  0.59%)
#     Label    2.0:    90525 voxels (  0.41%)
#     Label    3.0:  4926092 voxels ( 22.37%)
#     Label    4.0:   586116 voxels (  2.66%)
#   Total voxels: 22020096
# ------------------------------------------------------------
# SL043_left_CT2.nii.gz:
#   Data shape: (256, 512, 167)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 13858331 voxels ( 63.31%)
#     Label    1.0:   121091 voxels (  0.55%)
#     Label    2.0:    80466 voxels (  0.37%)
#     Label    3.0:  7283123 voxels ( 33.27%)
#     Label    4.0:   546013 voxels (  2.49%)
#   Total voxels: 21889024
# ------------------------------------------------------------
# SL043_right_CT2.nii.gz:
#   Data shape: (256, 512, 167)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 14446731 voxels ( 66.00%)
#     Label    1.0:   118632 voxels (  0.54%)
#     Label    2.0:    69030 voxels (  0.32%)
#     Label    3.0:  6705063 voxels ( 30.63%)
#     Label    4.0:   549568 voxels (  2.51%)
#   Total voxels: 21889024
# ------------------------------------------------------------
# TW057_left_CT2.nii.gz:
#   Data shape: (256, 512, 184)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 19117637 voxels ( 79.27%)
#     Label    1.0:   186158 voxels (  0.77%)
#     Label    2.0:   123637 voxels (  0.51%)
#     Label    3.0:  4055552 voxels ( 16.82%)
#     Label    4.0:   634264 voxels (  2.63%)
#   Total voxels: 24117248
# ------------------------------------------------------------
# TW057_right_CT2.nii.gz:
#   Data shape: (256, 512, 184)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 19342100 voxels ( 80.20%)
#     Label    1.0:   182315 voxels (  0.76%)
#     Label    2.0:   106680 voxels (  0.44%)
#     Label    3.0:  3813613 voxels ( 15.81%)
#     Label    4.0:   672540 voxels (  2.79%)
#   Total voxels: 24117248
# ------------------------------------------------------------
# VH053_left_CT2.nii.gz:
#   Data shape: (256, 512, 212)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 21565994 voxels ( 77.61%)
#     Label    1.0:   188460 voxels (  0.68%)
#     Label    2.0:   227211 voxels (  0.82%)
#     Label    3.0:  5094976 voxels ( 18.34%)
#     Label    4.0:   710623 voxels (  2.56%)
#   Total voxels: 27787264
# ------------------------------------------------------------
# VH053_right_CT2.nii.gz:
#   Data shape: (256, 512, 212)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 22017179 voxels ( 79.23%)
#     Label    1.0:   194359 voxels (  0.70%)
#     Label    2.0:   192410 voxels (  0.69%)
#     Label    3.0:  4688044 voxels ( 16.87%)
#     Label    4.0:   695272 voxels (  2.50%)
#   Total voxels: 27787264
# ------------------------------------------------------------
# Analysis complete!
# ================================================================================
# Success Status:  True

# %%
import nibabel as nib
import numpy as np
import os
import glob

label_dir = "/home/user/auto-annotation/auto-annotation/dataset/femur-bone/data/label/CT3"
# Get all .nii.gz files in the directory
nifti_files = glob.glob(os.path.join(label_dir, "*.nii.gz"))
print(f"\nFound {len(nifti_files)} NIfTI files in {label_dir}")
print("="*80)

success = True
# Process each file
for file_path in sorted(nifti_files):
    try:
        # Load the NIfTI file
        img = nib.load(file_path)
        data = img.get_fdata()
        
        # Get unique labels
        unique_labels = np.unique(data)
        if len(unique_labels) != 5:
            success = False
        
        # Get just the filename for cleaner output
        filename = os.path.basename(file_path)
        
        print(f"{filename}:")
        print(f"  Data shape: {data.shape}")
        print(f"  Data type: {data.dtype}")
        print(f"  Number of unique labels: {len(unique_labels)}")
        print(f"  Label analysis:")
        
        # Calculate volume (voxel count) for each unique label
        total_voxels = data.size
        for label in unique_labels:
            voxel_count = np.sum(data == label)
            percentage = (voxel_count / total_voxels) * 100
            print(f"    Label {label:>6}: {voxel_count:>8} voxels ({percentage:>6.2f}%)")
        
        print(f"  Total voxels: {total_voxels}")
        print("-" * 60)
        
    except Exception as e:
        filename = os.path.basename(file_path)
        print(f"Error loading {filename}: {str(e)}")
        print("-" * 60)

print("Analysis complete!")
print("="*80)
print("Success Status: ", success)
# Out:
# Found 14 NIfTI files in /home/user/auto-annotation/auto-annotation/dataset/femur-bone/data/label/CT3
# ================================================================================
# RG018_Left_CT3.nii.gz:
#   Data shape: (538, 512, 256)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 58505166 voxels ( 82.97%)
#     Label    1.0:   434891 voxels (  0.62%)
#     Label    2.0:   305606 voxels (  0.43%)
#     Label    3.0: 10107476 voxels ( 14.33%)
#     Label    4.0:  1163597 voxels (  1.65%)
#   Total voxels: 70516736
# ------------------------------------------------------------
# RG018_right_CT3.nii.gz:
#   Data shape: (256, 512, 538)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 60012324 voxels ( 85.10%)
#     Label    1.0:   423526 voxels (  0.60%)
#     Label    2.0:   249008 voxels (  0.35%)
#     Label    3.0:  7928872 voxels ( 11.24%)
#     Label    4.0:  1903006 voxels (  2.70%)
#   Total voxels: 70516736
# ------------------------------------------------------------
# RP036_left_CT3.nii.gz:
#   Data shape: (256, 512, 290)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 28767565 voxels ( 75.68%)
#     Label    1.0:   174620 voxels (  0.46%)
#     Label    2.0:   237110 voxels (  0.62%)
#     Label    3.0:  7626552 voxels ( 20.06%)
#     Label    4.0:  1205033 voxels (  3.17%)
#   Total voxels: 38010880
# ------------------------------------------------------------
# RT023_left_CT3.nii.gz:
#   Data shape: (256, 512, 415)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 42678092 voxels ( 78.46%)
#     Label    1.0:   248866 voxels (  0.46%)
#     Label    2.0:   293437 voxels (  0.54%)
#     Label    3.0:  9500674 voxels ( 17.47%)
#     Label    4.0:  1673811 voxels (  3.08%)
#   Total voxels: 54394880
# ------------------------------------------------------------
# SB032_left_CT3.nii.gz:
#   Data shape: (256, 512, 552)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 60285163 voxels ( 83.32%)
#     Label    1.0:   439820 voxels (  0.61%)
#     Label    2.0:   332882 voxels (  0.46%)
#     Label    3.0:  9294360 voxels ( 12.85%)
#     Label    4.0:  1999519 voxels (  2.76%)
#   Total voxels: 72351744
# ------------------------------------------------------------
# SB032_right_CT3.nii.gz:
#   Data shape: (256, 512, 552)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 59613624 voxels ( 82.39%)
#     Label    1.0:   464694 voxels (  0.64%)
#     Label    2.0:   283514 voxels (  0.39%)
#     Label    3.0: 10040583 voxels ( 13.88%)
#     Label    5.0:  1949329 voxels (  2.69%)
#   Total voxels: 72351744
# ------------------------------------------------------------
# SL015_left_CT3.nii.gz:
#   Data shape: (256, 512, 509)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 49301180 voxels ( 73.90%)
#     Label    1.0:   335347 voxels (  0.50%)
#     Label    2.0:   264142 voxels (  0.40%)
#     Label    3.0: 15147897 voxels ( 22.71%)
#     Label    4.0:  1667082 voxels (  2.50%)
#   Total voxels: 66715648
# ------------------------------------------------------------
# SL015_right_CT3.nii.gz:
#   Data shape: (256, 512, 509)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 50858192 voxels ( 76.23%)
#     Label    1.0:   339995 voxels (  0.51%)
#     Label    2.0:   233707 voxels (  0.35%)
#     Label    3.0: 13543212 voxels ( 20.30%)
#     Label    4.0:  1740542 voxels (  2.61%)
#   Total voxels: 66715648
# ------------------------------------------------------------
# SL043_left_CT3.nii.gz:
#   Data shape: (256, 512, 508)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 44043559 voxels ( 66.15%)
#     Label    1.0:   311904 voxels (  0.47%)
#     Label    2.0:   211265 voxels (  0.32%)
#     Label    3.0: 20394300 voxels ( 30.63%)
#     Label    4.0:  1623548 voxels (  2.44%)
#   Total voxels: 66584576
# ------------------------------------------------------------
# SL043_right_CT3.nii.gz:
#   Data shape: (256, 512, 508)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 45364235 voxels ( 68.13%)
#     Label    1.0:   308464 voxels (  0.46%)
#     Label    2.0:   183696 voxels (  0.28%)
#     Label    3.0: 19090777 voxels ( 28.67%)
#     Label    4.0:  1637404 voxels (  2.46%)
#   Total voxels: 66584576
# ------------------------------------------------------------
# TW057_left_CT3.nii.gz:
#   Data shape: (256, 512, 557)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 59574644 voxels ( 81.60%)
#     Label    1.0:   495634 voxels (  0.68%)
#     Label    2.0:   322487 voxels (  0.44%)
#     Label    3.0: 10727479 voxels ( 14.69%)
#     Label    4.0:  1886860 voxels (  2.58%)
#   Total voxels: 73007104
# ------------------------------------------------------------
# TW057_right_CT3.nii.gz:
#   Data shape: (256, 512, 557)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 60123342 voxels ( 82.35%)
#     Label    1.0:   487611 voxels (  0.67%)
#     Label    2.0:   285179 voxels (  0.39%)
#     Label    3.0: 10107249 voxels ( 13.84%)
#     Label    4.0:  2003723 voxels (  2.74%)
#   Total voxels: 73007104
# ------------------------------------------------------------
# VH053_left_CT3.nii.gz:
#   Data shape: (256, 512, 641)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 67424684 voxels ( 80.25%)
#     Label    1.0:   499155 voxels (  0.59%)
#     Label    2.0:   589800 voxels (  0.70%)
#     Label    3.0: 13395631 voxels ( 15.94%)
#     Label    4.0:  2107882 voxels (  2.51%)
#   Total voxels: 84017152
# ------------------------------------------------------------
# VH053_right_CT3.nii.gz:
#   Data shape: (256, 512, 641)
#   Data type: float64
#   Number of unique labels: 5
#   Label analysis:
#     Label    0.0: 68579771 voxels ( 81.63%)
#     Label    1.0:   501315 voxels (  0.60%)
#     Label    2.0:   503660 voxels (  0.60%)
#     Label    3.0: 12370666 voxels ( 14.72%)
#     Label    4.0:  2061740 voxels (  2.45%)
#   Total voxels: 84017152
# ------------------------------------------------------------
# Analysis complete!
# ================================================================================
# Success Status:  True

# %%
! pip install nibabel numpy
# Out:
# Requirement already satisfied: nibabel in /home/user/anaconda3/lib/python3.11/site-packages (5.3.2)
# Requirement already satisfied: numpy in /home/user/anaconda3/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: importlib-resources>=5.12 in /home/user/anaconda3/lib/python3.11/site-packages (from nibabel) (6.5.2)
# Requirement already satisfied: packaging>=20 in /home/user/anaconda3/lib/python3.11/site-packages (from nibabel) (23.1)
# Requirement already satisfied: typing-extensions>=4.6 in /home/user/anaconda3/lib/python3.11/site-packages (from nibabel) (4.15.0)

# %%
file_path = "/home/user/auto-annotation/auto-annotation/segmentation_labels.nii.gz"

try:
    # Load the NIfTI file
    img = nib.load(file_path)
    data = img.get_fdata()
    
    # Get unique labels
    unique_labels = np.unique(data)
    
    # Get just the filename for cleaner output
    filename = os.path.basename(file_path)
    
    print(f"{filename}:")
    print(f"  Data shape: {data.shape}")
    print(f"  Data type: {data.dtype}")
    print(f"  Number of unique labels: {len(unique_labels)}")
    print(f"  Label analysis:")
    
    # Calculate volume (voxel count) for each unique label
    total_voxels = data.size
    for label in unique_labels:
        voxel_count = np.sum(data == label)
        percentage = (voxel_count / total_voxels) * 100
        print(f"    Label {label:>6}: {voxel_count:>8} voxels ({percentage:>6.2f}%)")
    
    print(f"  Total voxels: {total_voxels}")
    print("-" * 60)
    
except Exception as e:
    filename = os.path.basename(file_path)
    print(f"Error loading {filename}: {str(e)}")
    print("-" * 60)
# Out:
# segmentation_labels.nii.gz:
#   Data shape: (415, 512, 256)
#   Data type: float64
#   Number of unique labels: 2
#   Label analysis:
#     Label    0.0: 54146014 voxels ( 99.54%)
#     Label    1.0:   248866 voxels (  0.46%)
#   Total voxels: 54394880
# ------------------------------------------------------------
